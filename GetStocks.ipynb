# %% [markdown]
# ## This notebook uses quandl to grab stock info

# %%
import pandas as pd
import quandl
import datetime 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
start = datetime.datetime(2015,1,1) # Beginning of period 
end = datetime.datetime(2018,1,1) # End of period

# %%
stock = "AAPL" # some stock label we are interested in
apple = quandl.get("WIKI/" + stock, start_date=start, end_date=end) #download data with quandl
apple["20d"] = np.round(apple["Close"].rolling(window = 20, center = False).mean(), 2) # 20 day moving average

# %%
pylab.rcParams['figure.figsize'] = (15, 9)
plt.title(stock + " Closing Prices")
apple["Close"].plot() # plot daily closing prices 
apple["20d"].plot() # plot 20 day rolling average 
plt.show()
