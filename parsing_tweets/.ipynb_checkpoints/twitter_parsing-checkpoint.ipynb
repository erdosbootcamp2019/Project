# %%
import pandas as pd

# %%
df = pd.read_csv('../using_twint/musks_tweets.csv')

# %%
df.head()
# Out:
#                    id     conversation_id     created_at        date  \
# 0  945814723521417217  945712432416137217  1514334777000  2017-12-26
# 1  945749747129659392  945712432416137217  1514319285000  2017-12-26
# 2  945748731197980672  945712432416137217  1514319043000  2017-12-26
# 3  945730195113365504  945727773493968896  1514314623000  2017-12-26
# 4  945729852874694656  945712432416137217  1514314542000  2017-12-26
#
#        time timezone   user_id  username       name  place  \
# 0  19:32:57      EDT  44196397  elonmusk  Elon Musk    NaN
# 1  15:14:45      EDT  44196397  elonmusk  Elon Musk    NaN
# 2  15:10:43      EDT  44196397  elonmusk  Elon Musk    NaN
# 3  13:57:03      EDT  44196397  elonmusk  Elon Musk    NaN
# 4  13:55:42      EDT  44196397  elonmusk  Elon Musk    NaN
#
#                          ...                         retweets_count  \
# 0                        ...                                     70
# ...

# %%
df.iloc[0]['tweet']
# Out:
# 'Coming very soon'
